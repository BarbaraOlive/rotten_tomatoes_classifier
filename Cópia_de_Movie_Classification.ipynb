# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os


sns.set_palette('rainbow',8, 0.45)

# %%
# to run when local
files_path = 'Files'

# %%
# loading datasets when local
rt_movies = pd.read_csv(os.path.join(files_path, "rt_movies.csv"), index_col=0)
rt_reviews = pd.read_csv(os.path.join(files_path, "rt_reviews.csv"), index_col=0)

# %%
rt_reviews.head()
# Out:
#   rotten_tomatoes_link      critic_name  top_critic           publisher_name  \
# 0            m/0814255  Andrew L. Urban       False           Urban Cinefile
# 1            m/0814255    Louise Keller       False           Urban Cinefile
# 2            m/0814255              NaN       False      FILMINK (Australia)
# 3            m/0814255     Ben McEachen       False  Sunday Mail (Australia)
# 4            m/0814255      Ethan Alter        True       Hollywood Reporter
#
#   review_type review_score review_date  \
# 0       Fresh          NaN  2010-02-06
# 1       Fresh          NaN  2010-02-06
# 2       Fresh          NaN  2010-02-09
# 3       Fresh        3.5/5  2010-02-09
# 4      Rotten          NaN  2010-02-10
#
#                                       review_content  review_year
# 0  A fantasy adventure that fuses Greek mythology...         2010
# 1  Uma Thurman as Medusa, the gorgon with a coiff...         2010
# 2  With a top-notch cast and dazzling special eff...         2010
# 3  Whether audiences will get behind The Lightnin...         2010
# 4  What's really lacking in The Lightning Thief i...         2010

# %% [markdown]
# ## Modelagem

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score
import scikitplot as skplt
import pickle

# %%
rt = rt_reviews[['review_content', 'review_type']]

# %%
rt.review_type.value_counts()
# Out:
# Fresh     681035
# Rotten    383176
# Name: review_type, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = rt['review_content']
y = rt['review_type']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=42, 
                                                    stratify=df['review_type'])

# %% [markdown]
# ### Regressão Logística

# %%
# Regressão Logística
from sklearn.linear_model import LogisticRegression

class_reglog = Pipeline([('tfidf', TfidfVectorizer()),
                    ('class',  LogisticRegression(solver='newton-cg', max_iter=500))])

class_reglog.fit(X_train, y_train)
y_reglog = class_reglog.predict(X_test)
y_proba_reglog = class_reglog.predict_proba(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [33], in <cell line: 7>()
#       2 from sklearn.linear_model import LogisticRegression
#       4 class_reglog = Pipeline([('tfidf', TfidfVectorizer()),
#       5                     ('class',  LogisticRegression(solver='newton-cg', max_iter=500))])
# ----> 7 class_reglog.fit(X_train, y_train)
#       8 y_reglog = class_reglog.predict(X_test)
#       9 y_proba_reglog = class_reglog.predict_proba(X_test)
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\sklearn\pipeline.py:394, in Pipeline.fit(self, X, y, **fit_params)
#     392     if self._final_estimator != "passthrough":
#     393         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 394         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     396 return self
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\sklearn\linear_model\_logistic.py:1589, in LogisticRegression.fit(self, X, y, sample_weight)
#    1587 else:
#    1588     prefer = "processes"
# -> 1589 fold_coefs_ = Parallel(
#    1590     n_jobs=self.n_jobs,
#    1591     verbose=self.verbose,
#    1592     **_joblib_parallel_args(prefer=prefer),
#    1593 )(
#    1594     path_func(
#    1595         X,
#    1596         y,
#    1597         pos_class=class_,
#    1598         Cs=[C_],
#    1599         l1_ratio=self.l1_ratio,
#    1600         fit_intercept=self.fit_intercept,
#    1601         tol=self.tol,
#    1602         verbose=self.verbose,
#    1603         solver=solver,
#    1604         multi_class=multi_class,
#    1605         max_iter=self.max_iter,
#    1606         class_weight=self.class_weight,
#    1607         check_input=False,
#    1608         random_state=self.random_state,
#    1609         coef=warm_start_coef_,
#    1610         penalty=penalty,
#    1611         max_squared_sum=max_squared_sum,
#    1612         sample_weight=sample_weight,
#    1613     )
#    1614     for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1615 )
#    1617 fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#    1618 self.n_iter_ = np.asarray(n_iter_, dtype=np.int32)[:, 0]
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\joblib\parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\sklearn\linear_model\_logistic.py:823, in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     821 elif solver == "newton-cg":
#     822     args = (X, target, 1.0 / C, sample_weight)
# --> 823     w0, n_iter_i = _newton_cg(
#     824         hess, func, grad, w0, args=args, maxiter=max_iter, tol=tol
#     825     )
#     826 elif solver == "liblinear":
#     827     coef_, intercept_, n_iter_i, = _fit_liblinear(
#     828         X,
#     829         target,
#    (...)
#     840         sample_weight=sample_weight,
#     841     )
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\sklearn\utils\optimize.py:193, in _newton_cg(grad_hess, func, grad, x0, args, tol, maxiter, maxinner, line_search, warn)
#     189 termcond = eta * maggrad
#     191 # Inner loop: solve the Newton update by conjugate gradient, to
#     192 # avoid inverting the Hessian
# --> 193 xsupi = _cg(fhess_p, fgrad, maxiter=maxinner, tol=termcond)
#     195 alphak = 1.0
#     197 if line_search:
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\sklearn\utils\optimize.py:88, in _cg(fhess_p, fgrad, maxiter, tol)
#      85 if np.sum(np.abs(ri)) <= tol:
#      86     break
# ---> 88 Ap = fhess_p(psupi)
#      89 # check curvature
#      90 curv = np.dot(psupi, Ap)
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\sklearn\linear_model\_logistic.py:235, in _logistic_grad_hess.<locals>.Hs(s)
#     233 ret = np.empty_like(s)
#     234 if sparse.issparse(X):
# --> 235     ret[:n_features] = X.T.dot(dX.dot(s[:n_features]))
#     236 else:
#     237     ret[:n_features] = np.linalg.multi_dot([X.T, dX, s[:n_features]])
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\scipy\sparse\_base.py:413, in spmatrix.dot(self, other)
#     400 def dot(self, other):
#     401     """Ordinary dot product
#     402
#     403     Examples
#    (...)
#     411
#     412     """
# --> 413     return self @ other
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\scipy\sparse\_base.py:620, in spmatrix.__matmul__(self, other)
#     617 if isscalarlike(other):
#     618     raise ValueError("Scalar operands are not allowed, "
#     619                      "use '*' instead")
# --> 620 return self._mul_dispatch(other)
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\scipy\sparse\_base.py:521, in spmatrix._mul_dispatch(self, other)
#     518 if other.__class__ is np.ndarray:
#     519     # Fast path for the most common case
#     520     if other.shape == (N,):
# --> 521         return self._mul_vector(other)
#     522     elif other.shape == (N, 1):
#     523         return self._mul_vector(other.ravel()).reshape(M, 1)
#
# File ~\Documents\Particular\TCC\tccenv\lib\site-packages\scipy\sparse\_compressed.py:489, in _cs_matrix._mul_vector(self, other)
#     487 # csr_matvec or csc_matvec
#     488 fn = getattr(_sparsetools, self.format + '_matvec')
# --> 489 fn(M, N, self.indptr, self.indices, self.data, other, result)
#     491 return result
#
# KeyboardInterrupt:

# %%
print(classification_report(y_test, y_reglog))

# %%
auc_reglog = roc_auc_score(y_test, y_proba_reglog[:,1])
print('AUC: %.3f' % auc_reglog)
# Out:
# AUC: 0.893

# %%
skplt.metrics.plot_roc(y_test, y_proba_reglog)
plt.figure(figsize=(10,8))
plt.show()

# %%
pd.crosstab(y_test, y_reglog, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted   Fresh  Rotten     All
# True
# Fresh      182213   22098  204311
# Rotten      35134   79819  114953
# All        217347  101917  319264

# %%
#save file with pickle
filename = "class_reglog.p"
pickle.dump( class_reglog, open( filename, "wb" ))

# %% [markdown]
# ### Gradient Boosting

# %%
# XGBoost
from sklearn.ensemble import GradientBoostingClassifier

class_xgb = Pipeline([('tfidf', TfidfVectorizer()),
                    ('class', GradientBoostingClassifier())])

class_xgb.fit(X_train, y_train)
y_xgb = class_xgb.predict(X_test)
y_proba_xgb = class_xgb.predict_proba(X_test)

# %%
print(classification_report(y_test, y_xgb))
# Out:
#               precision    recall  f1-score   support
#
#        Fresh       0.67      0.98      0.80    204311
#       Rotten       0.81      0.14      0.24    114953
#
#     accuracy                           0.68    319264
#    macro avg       0.74      0.56      0.52    319264
# weighted avg       0.72      0.68      0.60    319264

# %%
auc_xgb = roc_auc_score(y_test, y_proba_xgb[:,1])
print('AUC: %.3f' % auc_xgb)
# Out:
# AUC: 0.724

# %%
skplt.metrics.plot_roc(y_test, y_proba_xgb)
plt.figure(figsize=(10,8))
plt.show()

# %%
pd.crosstab(y_test, y_xgb, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted   Fresh  Rotten     All
# True
# Fresh      200311    4000  204311
# Rotten      98352   16601  114953
# All        298663   20601  319264

# %%
#save file with pickle
filename = "class_xgb.p"
pickle.dump( class_xgb, open( filename, "wb" ))

# %% [markdown]
# ### SVC

# %%
# SVC
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

svm = LinearSVC()
clf = CalibratedClassifierCV(svm) 

class_svc = Pipeline([('tfidf', TfidfVectorizer()),
                    ('class', clf)])

class_svc.fit(X_train, y_train)
y_svc = class_svc.predict(X_test)
y_proba_svc = class_svc.predict_proba(X_test)

# %%
print(classification_report(y_test, y_svc))
# Out:
#               precision    recall  f1-score   support
#
#        Fresh       0.84      0.89      0.86    204311
#       Rotten       0.78      0.70      0.74    114953
#
#     accuracy                           0.82    319264
#    macro avg       0.81      0.79      0.80    319264
# weighted avg       0.82      0.82      0.82    319264

# %%
auc_svc = roc_auc_score(y_test, y_proba_svc[:,1])
print('AUC: %.3f' % auc_svc)
# Out:
# AUC: 0.893

# %%
skplt.metrics.plot_roc(y_test, y_proba_svc)
plt.figure(figsize=(10,8))
plt.show()

# %%
pd.crosstab(y_test, y_svc, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted   Fresh  Rotten     All
# True
# Fresh      181423   22888  204311
# Rotten      34381   80572  114953
# All        215804  103460  319264

# %%
#save file with pickle
filename = "class_svc.p"
pickle.dump( class_svc, open( filename, "wb" ))

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

class_knn = Pipeline([('tfidf', TfidfVectorizer()),
                    ('class', KNeighborsClassifier())])

class_knn.fit(X_train, y_train)
y_knn = class_knn.predict(X_test)
y_proba_knn = class_knn.predict_proba(X_test)

# %%
print(classification_report(y_test, y_knn))
# Out:
#               precision    recall  f1-score   support
#
#        Fresh       0.68      0.71      0.70    204311
#       Rotten       0.44      0.39      0.41    114953
#
#     accuracy                           0.60    319264
#    macro avg       0.56      0.55      0.56    319264
# weighted avg       0.59      0.60      0.59    319264

# %%
auc_knn = roc_auc_score(y_test, y_proba_knn[:,1])
print('AUC: %.3f' % auc_knn)
# Out:
# AUC: 0.584

# %%
skplt.metrics.plot_roc(y_test, y_proba_knn)
plt.figure(figsize=(10,8))
plt.show()

# %%
pd.crosstab(y_test, y_knn, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted   Fresh  Rotten     All
# True
# Fresh      146040   58271  204311
# Rotten      69655   45298  114953
# All        215695  103569  319264

# %%
#save file with pickle
filename = "class_knn.p"
pickle.dump( class_knn, open( filename, "wb" ))

# %% [markdown]
# ### Comparação dos Modelos

# %%
model_performance = [accuracy_score(y_test, y_svc),accuracy_score(y_test, y_reglog),accuracy_score(y_test, y_xgb),accuracy_score(y_test, y_knn)]
models = ['Linear SVC', 'Logistic Regression', 'XGBoost', 'KNN']
df_model = pd.DataFrame(model_performance, columns=['Accuracy'])
df_model['Model'] = models
df_model
# Out:
#    Accuracy                Model
# 0  0.820622           Linear SVC
# 1  0.820587  Logistic Regression
# 2  0.679413              XGBoost
# 3  0.599310                  KNN

# %% [markdown]
# ## Amostragem e Lematização

# %%
import json
import requests
import re
import string
import langid
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ### Preparação dos Dados

# %%
# Reduzindo os dados para poder aplicar a lematização. Dados estratificados por filme e tipo de review. 
rt_reviews_strat = rt_reviews.groupby(['rotten_tomatoes_link','review_type'], 
                                      group_keys=False).apply(lambda x: x.sample(frac=0.4))

# %%
rt_reviews_strat.shape
# Out:
# (425384, 9)

# %%
rt_reviews_strat['review_type'].value_counts()
# Out:
# Fresh     272305
# Rotten    153079
# Name: review_type, dtype: int64

# %%
df = rt_reviews_strat[['review_content', 'review_type']]

# %%
def lang_idf(df):
    '''Checa o texto para ver se a lingua escrita é inglês, se não for retorna Falso.
    Args:
        df: dataframe object.
    Returns: 
        df: dataframe object com coluna indicando a língua.'''
    lang = []
    for text in df['review_content']:
        lang.append(langid.classify(text)[0])
    df['lang_idf'] = lang
    
    return df

# %%
def prepare_text(df):
    '''Lemmatiza o texto para passar pelo modelo.
    
    Args:
        df: dataframe object.
    Returns:
        df: dataframe object com o texto preparado.'''

    mov_end = []

    for index, item in enumerate(nlp.pipe(df['review_content'], n_process=6, batch_size=2000)):
        doc = nlp(item)
        #text_tokens = " ".join([token.text for token in doc if not token.is_stop])
        #doc = [token for token in doc if not token.is_stop]
        lemmatized_sentence = " ".join([token.lemma_ for token in doc if not token.is_stop])
        #lemmatized_sentence = re.sub('[^a-zA-Z]', ' ', lemmatized_sentence)
        #lemmatized_sentence = lemmatized_sentence.translate(str.maketrans('', '', string.punctuation))
        #mov_end.append(text_tokens)
        mov_end.append(lemmatized_sentence)
        
    df['prepared_review_content'] = mov_end
    
    return df

# %%
df = lang_idf(df)
# Out:
# C:\Users\barbara.oliveira\AppData\Local\Temp\ipykernel_30292\3728544603.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lang_idf'] = lang

# %%
df = prepare_text(df)
# Out:
# C:\Users\barbara.oliveira\AppData\Local\Temp\ipykernel_30292\1037608836.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prepared_review_content'] = mov_end

# %%
df.loc[df.lang_idf == 'en'].shape
# Out:
# (420729, 5)

# %%
df = df.loc[df.lang_idf == 'en']

# %%
df.to_csv(os.path.join(files_path, "rt_reviews_prepared_english.csv"))

# %%
df.head()
# Out:
#                                            review_content review_type  \
# 658851  For romance junkies, the film checks all the b...       Fresh
# 658881  Therein lies the brilliance of Plus One: All o...       Fresh
# 658895  Erskine, with her earthy chuckle and precision...       Fresh
# 658893    A love story with its heart in the right place.       Fresh
# 658846  Plus One isn't much more than consistently amu...       Fresh
#
#                                   prepared_review_content lang_idf
# 658851                  romance junkie , film check box .       en
# 658881           lie brilliance plus : feel like happen .       en
# 658895  Erskine , earthy chuckle precision - tool comi...       en
# 658893                     love story heart right place .       en
# 658846  plus consistently amusing sweetly romantic , r...       en

# %% [markdown]
# ### Modelagem após processamento

# %%
from sklearn.model_selection import train_test_split

X = df['prepared_review_content']
y = df['review_type']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=42, 
                                                    stratify=df['review_type'])

# %% [markdown]
# ### Regressão Logística

# %%
# Regressão Logística
from sklearn.linear_model import LogisticRegression

class_reglog = Pipeline([('tfidf', TfidfVectorizer()),
                    ('class',  LogisticRegression(solver='lbfgs', max_iter=500))])

class_reglog.fit(X_train, y_train)
y_reglog = class_reglog.predict(X_test)
y_proba_reglog = class_reglog.predict_proba(X_test)

# %%
print(classification_report(y_test, y_reglog))
# Out:
#               precision    recall  f1-score   support
#
#        Fresh       0.81      0.89      0.85     80785
#       Rotten       0.76      0.63      0.69     45434
#
#     accuracy                           0.80    126219
#    macro avg       0.79      0.76      0.77    126219
# weighted avg       0.79      0.80      0.79    126219

# %%
auc_reglog = roc_auc_score(y_test, y_proba_reglog[:,1])
print('AUC: %.3f' % auc_reglog)
# Out:
# AUC: 0.866

# %%
skplt.metrics.plot_roc(y_test, y_proba_reglog)
plt.figure(figsize=(10,8))
plt.show()

# %%
pd.crosstab(y_test, y_reglog, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted  Fresh  Rotten     All
# True
# Fresh      71894    8891   80785
# Rotten     16757   28677   45434
# All        88651   37568  126219

# %%
#save file with pickle
filename = "class_lemm_reglog.p"
pickle.dump( class_reglog, open( filename, "wb" ))

# %% [markdown]
# ### Gradient Boosting

# %%
# XGBoost
from sklearn.ensemble import GradientBoostingClassifier

class_xgb = Pipeline([('tfidf', TfidfVectorizer()),
                    ('class', GradientBoostingClassifier())])

class_xgb.fit(X_train, y_train)
y_xgb = class_xgb.predict(X_test)
y_proba_xgb = class_xgb.predict_proba(X_test)

# %%
print(classification_report(y_test, y_xgb))
# Out:
#               precision    recall  f1-score   support
#
#        Fresh       0.67      0.98      0.80     80785
#       Rotten       0.79      0.14      0.24     45434
#
#     accuracy                           0.68    126219
#    macro avg       0.73      0.56      0.52    126219
# weighted avg       0.71      0.68      0.60    126219

# %%
auc_xgb = roc_auc_score(y_test, y_proba_xgb[:,1])
print('AUC: %.3f' % auc_xgb)
# Out:
# AUC: 0.708

# %%
skplt.metrics.plot_roc(y_test, y_proba_xgb)
plt.figure(figsize=(10,8))
plt.show()

# %%
pd.crosstab(y_test, y_xgb, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted   Fresh  Rotten     All
# True
# Fresh       79051    1734   80785
# Rotten      38943    6491   45434
# All        117994    8225  126219

# %%
#save file with pickle
filename = "class_lemm_xgb.p"
pickle.dump( class_xgb, open( filename, "wb" ))

# %% [markdown]
# ### SVC

# %%
# SVC
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

svm = LinearSVC()
clf = CalibratedClassifierCV(svm) 

class_svc = Pipeline([('tfidf', TfidfVectorizer()),
                    ('class', clf)])

class_svc.fit(X_train, y_train)
y_svc = class_svc.predict(X_test)
y_proba_svc = class_svc.predict_proba(X_test)

# %%
print(classification_report(y_test, y_svc))
# Out:
#               precision    recall  f1-score   support
#
#        Fresh       0.81      0.88      0.85     80785
#       Rotten       0.75      0.63      0.69     45434
#
#     accuracy                           0.79    126219
#    macro avg       0.78      0.76      0.77    126219
# weighted avg       0.79      0.79      0.79    126219

# %%
auc_svc = roc_auc_score(y_test, y_proba_svc[:,1])
print('AUC: %.3f' % auc_svc)
# Out:
# AUC: 0.861

# %%
skplt.metrics.plot_roc(y_test, y_proba_svc)
plt.figure(figsize=(10,8))
plt.show()

# %%
pd.crosstab(y_test, y_svc, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted  Fresh  Rotten     All
# True
# Fresh      71318    9467   80785
# Rotten     16598   28836   45434
# All        87916   38303  126219

# %%
#save file with pickle
filename = "class_lemm_svc.p"
pickle.dump( class_svc, open( filename, "wb" ))

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

class_knn = Pipeline([('tfidf', TfidfVectorizer()),
                    ('class', KNeighborsClassifier())])

class_knn.fit(X_train, y_train)
y_knn = class_knn.predict(X_test)
y_proba_knn = class_knn.predict_proba(X_test)

# %%
print(classification_report(y_test, y_knn))
# Out:
#               precision    recall  f1-score   support
#
#        Fresh       0.69      0.39      0.50     80785
#       Rotten       0.39      0.69      0.50     45434
#
#     accuracy                           0.50    126219
#    macro avg       0.54      0.54      0.50    126219
# weighted avg       0.58      0.50      0.50    126219

# %%
auc_knn = roc_auc_score(y_test, y_proba_knn[:,1])
print('AUC: %.3f' % auc_knn)
# Out:
# AUC: 0.554

# %%
skplt.metrics.plot_roc(y_test, y_proba_knn)
plt.figure(figsize=(10,8))
plt.show()

# %%
pd.crosstab(y_test, y_knn, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted  Fresh  Rotten     All
# True
# Fresh      31356   49429   80785
# Rotten     14201   31233   45434
# All        45557   80662  126219

# %%
#save file with pickle
filename = "class_lemm_knn.p"
pickle.dump( class_knn, open( filename, "wb" ))

# %% [markdown]
# ### Comparação dos Modelos

# %%
model_performance = [accuracy_score(y_test, y_svc),accuracy_score(y_test, y_reglog),accuracy_score(y_test, y_xgb),accuracy_score(y_test, y_knn)]
models = ['Linear SVC', 'Logistic Regression', 'XGBoost', 'KNN']
df_model = pd.DataFrame(model_performance, columns=['Accuracy'])
df_model['Model'] = models
df_model
# Out:
#    Accuracy                Model
# 0  0.793494           Linear SVC
# 1  0.796798  Logistic Regression
# 2  0.677727              XGBoost
# 3  0.495876                  KNN

# %% [markdown]
# ## Reviews dos usuários

# %%
import json
import requests
import re
import time
import string
from urllib.parse import urlparse

# %%
s = requests.Session()

# %%
def get_reviews(movie_url):
    r = requests.get(movie_url)
    movie_id = re.findall(r'(?<=movieId":")(.*)(?=","type)',r.text)[0]

    url = f"https://www.rottentomatoes.com/napi/movie/{movie_id}/reviews/user" #use reviews/userfor user reviews
    
    headers = {
    'Referer': 'https://www.rottentomatoes.com/m/notebook/reviews?type=user',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.108 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
        }
    
    payload = {
            'direction': 'next',
            'endCursor': '',
            'startCursor': '',
        }

    res = urlparse(movie_url)
    
    movie_link = []
    review_data = []

    while True:
            r = s.get(url, headers=headers, params=payload)
            data = r.json()

            if not data['pageInfo']['hasNextPage']:
                break

            payload['endCursor'] = data['pageInfo']['endCursor']
            payload['startCursor'] = data['pageInfo']['startCursor'] if data['pageInfo'].get('startCursor') else ''

            for index in range(0,len(data['reviews'])):
                movie_link.append(re.findall(r'(?<=\/)(.*?)(?=\/reviews)',res.path)[0])
                review_data.append(data['reviews'][index]['review'])

            time.sleep(1)

    #movie = pd.Series(review_data)
    movie = pd.DataFrame(
    {'rotten_tomatoes_link': movie_link, 'review_content': review_data}
        )
    
    return movie

# %%
movie = get_reviews('https://www.rottentomatoes.com/m/mother_2017/reviews')

# %%
movie.head()
# Out:
#   rotten_tomatoes_link                                     review_content
# 0        m/mother_2017  An intense, gorgeous and brilliant allegory. I...
# 1        m/mother_2017  too literal. lacks any kind of nuance. lacks c...
# 2        m/mother_2017  As though as it is to watch and understand, it...
# 3        m/mother_2017  This movie had me pissed off for 2 hours. Thou...
# 4        m/mother_2017  Mother! Is frustrating, stupidly surrealistic ...

# %%
movie.to_csv(os.path.join(files_path, "user_reviews_mother.csv"))

# %%
rt_reviews.loc[rt_reviews.rotten_tomatoes_link == 'm/mother_2017']['review_type'].value_counts()
# Out:
# Fresh     256
# Rotten    118
# Name: review_type, dtype: int64

# %%
rt_reviews.loc[rt_reviews.rotten_tomatoes_link == 'm/mother_2017']['review_type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='review_type'>

# %%
rt_reviews_strat.loc[rt_reviews_strat.rotten_tomatoes_link == 'm/mother_2017']['review_type'].value_counts()
# Out:
# Fresh     102
# Rotten     47
# Name: review_type, dtype: int64

# %%
movie = lang_idf(movie)

# %%
movie.shape
# Out:
# (3678, 3)

# %%
movie = movie.loc[movie.lang_idf == 'en']

# %%
movie.shape
# Out:
# (3544, 4)

# %%
movie = prepare_text(movie)

# %%
movie.head(10)
# Out:
#    rotten_tomatoes_link                                     review_content  \
# 0         m/mother_2017  An intense, gorgeous and brilliant allegory. I...
# 1         m/mother_2017  too literal. lacks any kind of nuance. lacks c...
# 2         m/mother_2017  As though as it is to watch and understand, it...
# 3         m/mother_2017  This movie had me pissed off for 2 hours. Thou...
# 4         m/mother_2017  Mother! Is frustrating, stupidly surrealistic ...
# 6         m/mother_2017  The most remarkable thing about this film is J...
# 7         m/mother_2017  This is very strange, confused me, in general ...
# 8         m/mother_2017  Everything in this movie is symbolic. You thin...
# 9         m/mother_2017            It is WILD ride, while also depressing.
# 10        m/mother_2017  Fuck it. They are playing with our emotions. W...
#
#    lang_idf                            prepared_review_content
# 0        en  intense , gorgeous brilliant allegory . little...
# 1        en  literal . lack kind nuance . lack creativity e...
# 2        en      watch understand , brilliantly direct think .
# 3        en  movie piss 2 hour . thought ending massively g...
# 4        en  mother ! frustrating , stupidly surrealistic d...
# 6        en  remarkable thing film Jennifer Lawrence perfor...
# 7        en            strange , confuse , general know like .
# 8        en  movie symbolic . think go sense , . movie stre...
# 9        en                           wild ride , depressing .
# 10       en  fuck . play emotion . bad movie see entire lif...

# %%
movie['class_pred'] = class_reglog.predict(movie['prepared_review_content'])
# Out:
# C:\Users\barbara.oliveira\AppData\Local\Temp\ipykernel_30292\1996527716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['class_pred'] = class_reglog.predict(movie['prepared_review_content'])

# %%
movie.head(10)
# Out:
#    rotten_tomatoes_link                                     review_content  \
# 0         m/mother_2017  An intense, gorgeous and brilliant allegory. I...
# 1         m/mother_2017  too literal. lacks any kind of nuance. lacks c...
# 2         m/mother_2017  As though as it is to watch and understand, it...
# 3         m/mother_2017  This movie had me pissed off for 2 hours. Thou...
# 4         m/mother_2017  Mother! Is frustrating, stupidly surrealistic ...
# 6         m/mother_2017  The most remarkable thing about this film is J...
# 7         m/mother_2017  This is very strange, confused me, in general ...
# 8         m/mother_2017  Everything in this movie is symbolic. You thin...
# 9         m/mother_2017            It is WILD ride, while also depressing.
# 10        m/mother_2017  Fuck it. They are playing with our emotions. W...
#
#    lang_idf                            prepared_review_content class_pred
# 0        en  intense , gorgeous brilliant allegory . little...      Fresh
# 1        en  literal . lack kind nuance . lack creativity e...     Rotten
# 2        en      watch understand , brilliantly direct think .      Fresh
# 3        en  movie piss 2 hour . thought ending massively g...     Rotten
# 4        en  mother ! frustrating , stupidly surrealistic d...      Fresh
# 6        en  remarkable thing film Jennifer Lawrence perfor...      Fresh
# 7        en            strange , confuse , general know like .     Rotten
# 8        en  movie symbolic . think go sense , . movie stre...     Rotten
# 9        en                           wild ride , depressing .      Fresh
# 10       en  fuck . play emotion . bad movie see entire lif...     Rotten

# %%
print(movie.review_content[8])
# Out:
# Everything in this movie is symbolic. You think it's going to make sense, but it doesn't. This movie was so stressful. It's like a bad dream. Paired with an unnecessary, disturbing ending.  So many great movies to see and I got stuck watching this garbage.

# %%
movie.class_pred.value_counts()
# Out:
# Rotten    1941
# Fresh     1603
# Name: class_pred, dtype: int64

# %%
movie.class_pred.value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='class_pred'>

# %%
movie.to_csv(os.path.join(files_path, "user_reviews_mother_classified.csv"))

# %% [markdown]
# ## WordCloud

# %%
#stopwords = set(STOPWORDS)
stopwords = STOP_WORDS
stopwords.update(['film', 'one', 'movie', 'review', 'make', 'even', 'mena'])

text = merged[merged.split_genres =='Horror'].iloc[0:100].review_content.tolist()
text = [lemmatizer.lemmatize(word) for word in text]
text = ' '.join(text).lower()
text = re.sub("\'\w+", '', text)
text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)


wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                #max_words = 60,
                min_font_size = 10).generate(text)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
text = merged[merged.split_genres =='Horror'].iloc[0:50].review_content.tolist()
text = ' '.join(text).lower()
text = re.sub("\'\w+", '', text)
text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)
#text = nltk.word_tokenize(text)
#lemmatized_string = ' '.join([lemmatizer.lemmatize(words) for words in text])

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                #max_words = 60,
                min_font_size = 10).generate(lemmatized_sentence)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
